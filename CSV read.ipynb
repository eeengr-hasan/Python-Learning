# %%
import pandas as pd

# %%
csv_file = pd.read_csv("Normal1.csv")

# %%
csv_file.iloc[:, :]
# Out:
#         EEG 1   EEG 2  EEG 3  EEG 4  EEG 5  EEG 6  EEG 7  EEG 8  \
# 0       1.724   6.588  1.630 -5.290 -1.289 -4.498 -8.286 -5.412
# 1       4.002   9.378  3.268 -3.460  1.422 -0.025 -5.045 -3.804
# 2       6.088  11.616  5.175 -1.802  4.326  3.241 -1.780 -2.350
# 3       7.399  13.117  6.941 -0.385  7.132  4.081  0.870 -0.114
# 4       8.745  14.713  9.037  1.228  9.877  4.133  2.716  2.676
# ...       ...     ...    ...    ...    ...    ...    ...    ...
# 80147  -8.201  -5.315 -2.955 -1.456  2.089  1.480  1.975  2.695
# 80148 -10.066  -6.334 -4.248 -3.425  0.511  1.148  0.729  1.128
# 80149  -4.802  -2.440 -2.163 -2.190  0.568  2.871  0.851  0.661
# 80150   5.375   4.252  3.086  1.612  2.063  5.158  1.434  1.457
# 80151  14.057   9.049  7.990  5.250  3.575  5.769  1.898  2.979
#
#        Accelerometer X  Accelerometer Y  Accelerometer Z  Gyroscope X  \
# 0               -0.117            0.913           -0.379       -0.732
# ...

# %%
csv_file.iloc[:, 0:8]
# Out:
#         EEG 1   EEG 2  EEG 3  EEG 4  EEG 5  EEG 6  EEG 7  EEG 8
# 0       1.724   6.588  1.630 -5.290 -1.289 -4.498 -8.286 -5.412
# 1       4.002   9.378  3.268 -3.460  1.422 -0.025 -5.045 -3.804
# 2       6.088  11.616  5.175 -1.802  4.326  3.241 -1.780 -2.350
# 3       7.399  13.117  6.941 -0.385  7.132  4.081  0.870 -0.114
# 4       8.745  14.713  9.037  1.228  9.877  4.133  2.716  2.676
# ...       ...     ...    ...    ...    ...    ...    ...    ...
# 80147  -8.201  -5.315 -2.955 -1.456  2.089  1.480  1.975  2.695
# 80148 -10.066  -6.334 -4.248 -3.425  0.511  1.148  0.729  1.128
# 80149  -4.802  -2.440 -2.163 -2.190  0.568  2.871  0.851  0.661
# 80150   5.375   4.252  3.086  1.612  2.063  5.158  1.434  1.457
# 80151  14.057   9.049  7.990  5.250  3.575  5.769  1.898  2.979
#
# [80152 rows x 8 columns]
