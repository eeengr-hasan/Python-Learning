# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("dataset/test/dogs/dog_563.jpg")

# %%
image
# Out:
# array([[[ 51,  83,  66],
#         [ 49,  81,  64],
#         [ 48,  80,  63],
#         ...,
#         [ 53,  93,  75],
#         [ 56,  94,  76],
#         [ 58,  96,  78]],
#
#        [[ 52,  84,  67],
#         [ 50,  82,  65],
#         [ 48,  80,  63],
#         ...,
#         [ 55,  95,  77],
#         [ 56,  94,  76],
#         [ 57,  95,  77]],
#
#        [[ 52,  84,  67],
#         [ 50,  82,  65],
#         [ 48,  80,  63],
#         ...,
#         [ 57,  97,  79],
#         [ 57,  95,  77],
#         [ 56,  94,  76]],
#
#        ...,
#
#        [[ 76,  61, 153],
#         [ 76,  61, 153],
#         [ 76,  61, 153],
#         ...,
#         [ 84, 100, 183],
#         [ 85, 101, 184],
#         [ 87, 103, 186]],
#
#        [[ 78,  63, 155],
#         [ 78,  63, 155],
#         [ 77,  62, 154],
#         ...,
#         [ 83,  99, 182],
#         [ 86, 102, 185],
#         [ 88, 104, 187]],
#
#        [[ 81,  66, 158],
#         [ 80,  65, 157],
#         [ 79,  64, 156],
# ...

# %%
image.shape
# Out:
# (1728, 3072, 3)

# %%
plt.imshow(image)
